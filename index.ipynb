# %% [markdown]
# # <center>Deep Neural Language processing</center>
#
# <br />
# <br />
# <br />
# <br />
#
# Bohdan Bilonoh

# %% [markdown]
# # Everething Starts with Embeddings
#
# <center> <img src="https://miro.medium.com/max/3010/1*OEmWDt4eztOcm5pr2QbxfA.png"> </center>

# %% [markdown]
# <center> <img src="https://cdn-images-1.medium.com/max/1024/1*mLrheV1nGz7XemDAVRcZ4A.png"> </center>

# %% [markdown]
# # New Era for RNNs
#
# <center> <img src="https://miro.medium.com/max/627/1*go8PHsPNbbV6qRiwpUQ5BQ.png"> </center>

# %% [markdown]
# <center> <img src="https://www.mdpi.com/energies/energies-13-00147/article_deploy/html/images/energies-13-00147-g008.png"> </center>

# %% [markdown]
# <center> <img src="https://discuss.pytorch.org/uploads/default/original/3X/7/0/709bbd6efd219c1b371c36b7cb64422cf42dc272.png"> </center>

# %% [markdown]
# # Steroids for Networks
#
# <center> <img src="https://miro.medium.com/max/666/0*VrRTrruwf2BtW4t5."> </center>

# %% [markdown]
# <center> <img src="https://www.researchgate.net/profile/Richard_Csaky3/publication/323587007/figure/fig6/AS:601280993046528@1520367968033/Visualizing-self-attention-lines-represent-the-weights-a-ij-Vaswani-et-al-2017.png"> </center>

# %% [markdown]
# <center> <img src="https://jhui.github.io/assets/att/attention.jpg"> </center>
